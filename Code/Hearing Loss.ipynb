# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
#get hearing loss prevalence from 1990-2010, all ages, both genders, US & UK
# https://vizhub.healthdata.org/gbd-results/

# %%
hloss = pd.read_csv("Rates_HearingLoss.csv")
hloss
# Out:
#     measure_id measure_name  location_id             location_name  sex_id  \
# 0            5   Prevalence           95            United Kingdom       3
# 1            5   Prevalence           95            United Kingdom       3
# 2            5   Prevalence           95            United Kingdom       3
# 3            5   Prevalence           95            United Kingdom       3
# 4            5   Prevalence           95            United Kingdom       3
# 5            5   Prevalence           95            United Kingdom       3
# 6            5   Prevalence           95            United Kingdom       3
# 7            5   Prevalence           95            United Kingdom       3
# 8            5   Prevalence           95            United Kingdom       3
# 9            5   Prevalence           95            United Kingdom       3
# 10           5   Prevalence           95            United Kingdom       3
# ...

# %%
df = pd.DataFrame(hloss)
df
# Out:
#     measure_id measure_name  location_id             location_name  sex_id  \
# 0            5   Prevalence           95            United Kingdom       3
# 1            5   Prevalence           95            United Kingdom       3
# 2            5   Prevalence           95            United Kingdom       3
# 3            5   Prevalence           95            United Kingdom       3
# 4            5   Prevalence           95            United Kingdom       3
# 5            5   Prevalence           95            United Kingdom       3
# 6            5   Prevalence           95            United Kingdom       3
# 7            5   Prevalence           95            United Kingdom       3
# 8            5   Prevalence           95            United Kingdom       3
# 9            5   Prevalence           95            United Kingdom       3
# 10           5   Prevalence           95            United Kingdom       3
# ...

# %%
#first plot for UK
#x is years, y is prevalence

df['year']
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# 19    2009
# 20    2010
# 21    1990
# 22    1991
# 23    1992
# 24    1993
# 25    1994
# 26    1995
# 27    1996
# 28    1997
# 29    1998
# 30    1999
# 31    2000
# 32    2001
# 33    2002
# 34    2003
# 35    2004
# 36    2005
# 37    2006
# 38    2007
# 39    2008
# 40    2009
# 41    2010
# Name: year, dtype: int64

# %%
x1 = df[['year']].iloc[:21]
x1 = x1['year']
x1
#x axis has years
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# 19    2009
# 20    2010
# Name: year, dtype: int64

# %%
#.loc is used on dataframes, specify row and column name, to get vales from specific column
uk  = df[df['location_name'] == 'United Kingdom']
uk
# Out:
#     measure_id measure_name  location_id   location_name  sex_id sex_name  \
# 0            5   Prevalence           95  United Kingdom       3     Both
# 1            5   Prevalence           95  United Kingdom       3     Both
# 2            5   Prevalence           95  United Kingdom       3     Both
# 3            5   Prevalence           95  United Kingdom       3     Both
# 4            5   Prevalence           95  United Kingdom       3     Both
# 5            5   Prevalence           95  United Kingdom       3     Both
# 6            5   Prevalence           95  United Kingdom       3     Both
# 7            5   Prevalence           95  United Kingdom       3     Both
# 8            5   Prevalence           95  United Kingdom       3     Both
# 9            5   Prevalence           95  United Kingdom       3     Both
# 10           5   Prevalence           95  United Kingdom       3     Both
# 11           5   Prevalence           95  United Kingdom       3     Both
# ...

# %%
uk['val']
#prevalence values of UK
# Out:
# 0     19106.900784
# 1     19139.287701
# 2     19176.512397
# 3     19212.378795
# 4     19249.560134
# 5     19294.733918
# 6     19331.548763
# 7     19379.583792
# 8     19430.183137
# 9     19475.512574
# 10    19523.190034
# 11    19375.049576
# 12    18974.447061
# 13    18452.869467
# 14    17960.809622
# 15    17662.402979
# 16    17547.783684
# 17    17534.880258
# 18    17582.965248
# 19    17661.907761
# 20    17750.644286
# Name: val, dtype: float64

# %%
y1 = uk['val'].tolist()
#y axis has values of UK

y1
# Out:
# [19106.90078363469,
#  19139.28770057581,
#  19176.51239705968,
#  19212.37879462148,
#  19249.560134414634,
#  19294.733918494363,
#  19331.548762885745,
#  19379.5837919988,
#  19430.183136610445,
#  19475.51257376241,
#  19523.19003384111,
#  19375.04957626275,
#  18974.44706054098,
#  18452.869467133525,
#  17960.809622464956,
#  17662.40297930234,
#  17547.783684476082,
#  17534.88025830667,
#  17582.965248280096,
#  17661.907760622104,
#  17750.644286006886]

# %%
ukchart = plt.figure(figsize=(14, 10))
ukchart = plt.plot(x1,y1)
plt.title(label= 'Prevalence of hearing loss rates from 1990-2010 in the UK')
plt.xlabel("Years")
plt.ylabel("Rates")
ukchart

# %%
us  = df[df['location_name'] == 'United States of America']
us
# Out:
#     measure_id measure_name  location_id             location_name  sex_id  \
# 21           5   Prevalence          102  United States of America       3
# 22           5   Prevalence          102  United States of America       3
# 23           5   Prevalence          102  United States of America       3
# 24           5   Prevalence          102  United States of America       3
# 25           5   Prevalence          102  United States of America       3
# 26           5   Prevalence          102  United States of America       3
# 27           5   Prevalence          102  United States of America       3
# 28           5   Prevalence          102  United States of America       3
# 29           5   Prevalence          102  United States of America       3
# 30           5   Prevalence          102  United States of America       3
# 31           5   Prevalence          102  United States of America       3
# ...

# %%
#Getting Y values for US
y2 = us['val'].tolist()
y2
# Out:
# [16603.807263649,
#  16744.382878756518,
#  16885.78552807625,
#  17027.044642805562,
#  17134.55734475406,
#  17254.430386805063,
#  17349.41722671112,
#  17458.106220859783,
#  17579.152572380903,
#  17670.77452699347,
#  17777.589690432895,
#  17865.139401373664,
#  17982.567706199923,
#  18121.18900067816,
#  18248.759075132373,
#  18411.010986716432,
#  18549.62525665999,
#  18709.659899484468,
#  18893.03907194066,
#  19073.735723688464,
#  19305.22542811571]

# %%
uschart = plt.figure(figsize=(14, 10))
uschart = plt.plot(x1,y2)
plt.title(label= 'Prevalence of hearing loss rates from 1990-2010 in the US')
plt.xlabel("Years")
plt.ylabel("Rates")
uschart

# %%
usukchart = plt.figure(figsize=(14, 10))
plt.plot(x1, y1, color='red', label='United Kingdom')
plt.plot(x1, y2, color='orange', label='United States of America')
plt.title(label= 'Prevalence of hearing loss cases from 1990-2010, for the USA and UK')
plt.xlabel("Years")
plt.ylabel("Cases in tens of millions")
plt.legend()
plt.grid(True)

usukchart

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(data= us, x = x, y = y2)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data= uk, x = x, y = y)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data= df, x = 'year', y = 'val', hue= 'location_name')
# Out:
# <AxesSubplot:xlabel='year', ylabel='val'>

# %%
#let's get the top 20 albums from years 1970-2010 and then find their dynamic ranges

query = '1970'
url = 'https://www.albumoftheyear.org/ratings/6-highest-rated/' + query + '/1'
page = requests.get('https://www.albumoftheyear.org/ratings/6-highest-rated/1970/1')
soup = BeautifulSoup(page.content, features="html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    Just a moment...
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet"/>
#  </head>
#  <body class="no-js">
#   <div class="main-wrapper" role="main">
#    <div class="main-content">
#     <noscript>
#      <div id="challenge-error-title">
#       <div class="h2">
#        <span class="icon-wrapper">
#         <div class="heading-icon warning-icon">
#         </div>
#        </span>
#        <span id="challenge-error-text">
#         Enable JavaScript and cookies to continue
#        </span>
#       </div>
#      </div>
#     </noscript>
# ...

# %%
for body in soup.find_all('body'):
    print(body)
# Out:
# <body class="no-js">
# <div class="main-wrapper" role="main">
# <div class="main-content">
# <noscript>
# <div id="challenge-error-title">
# <div class="h2">
# <span class="icon-wrapper">
# <div class="heading-icon warning-icon"></div>
# </span>
# <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# </div>
# </div>
# </noscript>
# <div id="trk_jschal_js" style="display:none;background-image:url('/cdn-cgi/images/trace/managed/nojs/transparent.gif?ray=7d925a5bc86f413a')"></div>
# <form action="/ratings/6-highest-rated/1970/1?__cf_chl_f_tk=Qu9mTWJhLjbp3fen8dtKqMyRglmrAJSLpjBgL0Vetqs-1687078942-0-gaNycGzNCuU" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# ...

# %%
from selenium import webdriver

dr = webdriver.Chrome()

site = 'https://www.albumoftheyear.org/ratings/6-highest-rated/'
query = 1970
url = site + str(query) + '/1'

dr.get(url)

bs = BeautifulSoup(dr.page_source,"lxml")

bs
# Out:
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#"><head>
# <title>The Best Albums of 1970 - Album of The Year</title>
# <meta content="The best music of 1970.  Music reviews, ratings, news and more.  See which albums are sitting at the top of this year's charts." name="Description"/>
# <meta content="Album of The Year" property="og:site_name"/>
# <meta content="The Best Albums of 1970" property="og:title"/>
# <meta content="article" property="og:type"/>
# <link href="https://www.albumoftheyear.org/ratings/6-highest-rated/1970/1" rel="canonical"/>
# <meta content="https://cdn.albumoftheyear.org/album/5650-american-beauty.jpg" property="og:image"/>
# ...

# %%
alblist = bs.find_all("h2", {"class": "albumListTitle"}, "span")
alblist
# Out:
# [<h2 class="albumListTitle"><span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><span class="albumListRank"><span itemprop="position">1</span>. </span><a href="/album/5650-grateful-dead-american-beauty.php" itemprop="url">Grateful Dead - American Beauty</a><meta content="Grateful Dead - American Beauty" itemprop="name"/></span></h2>,
#  <h2 class="albumListTitle"><span itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><span class="albumListRank"><span itemprop="position">2</span>. </span><a href="/album/6015-santana-abraxas.php" itemprop="url">Santana - Abraxas</a><meta content="Santana - Abraxas" itemprop="name"/></span></h2>,
# ...

# %%
bs.find_all("a", {"itemprop": "url"})
titles_list = bs.find_all("a", {"itemprop": "url"})
titles_list
# Out:
# [<a href="/album/5650-grateful-dead-american-beauty.php" itemprop="url">Grateful Dead - American Beauty</a>,
#  <a href="/album/6015-santana-abraxas.php" itemprop="url">Santana - Abraxas</a>,
#  <a href="/album/6035-the-stooges-funhouse.php" itemprop="url">The Stooges - Funhouse</a>,
#  <a href="/album/6039-miles-davis-bitches-brew.php" itemprop="url">Miles Davis - Bitches Brew</a>,
#  <a href="/album/6900-derek-and-the-dominos-layla-and-other-assorted-love-songs.php" itemprop="url">Derek and The Dominos - Layla and Other Assorted Love Songs</a>,
#  <a href="/album/5738-the-velvet-underground-loaded.php" itemprop="url">The Velvet Underground - Loaded</a>,
#  <a href="/album/6773-james-taylor-sweet-baby-james.php" itemprop="url">James Taylor - Sweet Baby James</a>,
#  <a href="/album/8866-randy-newman-12-songs.php" itemprop="url">Randy Newman - 12 Songs</a>,
#  <a href="/album/111239-the-last-poets-the-last-poets.php" itemprop="url">The Last Poets - The Last Poets</a>,
# ...

# %%
#top 10 albums for 1970
for x in range(10):
    print(titles_list[x].contents[0])
# Out:
# Grateful Dead - American Beauty
# Santana - Abraxas
# The Stooges - Funhouse
# Miles Davis - Bitches Brew
# Derek and The Dominos - Layla and Other Assorted Love Songs
# The Velvet Underground - Loaded
# James Taylor - Sweet Baby James
# Randy Newman - 12 Songs
# The Last Poets - The Last Poets
# Grateful Dead - Workingman's Dead

# %%
titles_list[3].contents
# Out:
# ['Miles Davis - Bitches Brew']

# %%
x = 1970

for i in range(41):
    
    dr = webdriver.Chrome()
    site = 'https://www.albumoftheyear.org/ratings/6-highest-rated/'
    
    query = x
    url = site + str(query) + '/1'
    dr.get(url)

    bs = BeautifulSoup(dr.page_source,"lxml")

    bs.find_all("a", {"itemprop": "url"})
    titles_list = bs.find_all("a", {"itemprop": "url"})


    with open ('top10albums1970-2010.csv', 'a') as v:
        
        # Write all the dictionary keys in a file with commas separated.
        #(this is adding column labels) we just need the titles once so we use any row/index for its titles
        v.write('\n')
        v.write("Year: " + str(x))
        v.write('\n') # Add a new line everytime a new entry is generated
        
        for j in range(10):

            v.write(titles_list[j].contents[0])
            v.write('\n') # Add a new line

            
    x +=1

# %%
#1971
dr = webdriver.Chrome()

site = 'https://www.albumoftheyear.org/ratings/6-highest-rated/'
query = 1971
url = site + str(query) + '/1'

dr.get(url)

bs = BeautifulSoup(dr.page_source,"lxml")

bs.find_all("a", {"itemprop": "url"})
titles_list = bs.find_all("a", {"itemprop": "url"})

titles_list

print("Top 10 Albums from " + str(query) + ":")

for x in range(10):
    print(str(x+1) + ". " + titles_list[x].contents[0])
# Out:
# Top 10 Albums from 1971:
# 1. David Bowie - Hunky Dory
# 2. Led Zeppelin - Led Zeppelin IV
# 3. Joni Mitchell - Blue
# 4. T. Rex - Electric Warrior
# 5. Mahavishnu Orchestra - The Inner Mounting Flame
# 6. The Rolling Stones - Sticky Fingers
# 7. Colin Blunstone - One Year
# 8. The Who - Who's Next
# 9. Can - Tago Mago
# 10. Rod Stewart - Every Picture Tells a Story

# %%
f = open("top10albums1970-2010.csv", "r")
print(f.read())
# Out:
# ,,,
# Year: 1970,,,
# Grateful Dead - American Beauty,,,
# Santana - Abraxas,,,
# The Stooges - Funhouse,,,
# Miles Davis - Bitches Brew,,,
# Derek and The Dominos - Layla and Other Assorted Love Songs,,,
# The Velvet Underground - Loaded,,,
# James Taylor - Sweet Baby James,,,
# Randy Newman - 12 Songs,,,
# The Last Poets - The Last Poets,,,
# Grateful Dead - Workingman's Dead,,,
# ,,,
# Year: 1971,,,
# David Bowie - Hunky Dory,,,
# Led Zeppelin - Led Zeppelin IV,,,
# Joni Mitchell - Blue,,,
# T. Rex - Electric Warrior,,,
# Mahavishnu Orchestra - The Inner Mounting Flame,,,
# The Rolling Stones - Sticky Fingers,,,
# Colin Blunstone - One Year,,,
# The Who - Who's Next,,,
# Can - Tago Mago,,,
# Rod Stewart - Every Picture Tells a Story,,,
# ,,,
# Year: 1972,,,
# David Bowie - The Rise and Fall of Ziggy Stardust and the Spiders from Mars,,,
# Stevie Wonder - Talking Book,,,
# Paul Simon - Paul Simon,,,
# Jimmy Cliff - The Harder They Come,,,
# Elton John - Honky Château,,,
# ...

# %%
top10 = pd.read_csv("top10albums1970-2010.csv")
top10
# Out:
#                                             Unnamed: 0  Unnamed: 1
# 0                                           Year: 1970         NaN
# 1                      Grateful Dead - American Beauty         NaN
# 2                                    Santana - Abraxas         NaN
# 3                               The Stooges - Funhouse         NaN
# 4                           Miles Davis - Bitches Brew         NaN
# ..                                                 ...         ...
# 486  Ali Farka Toure & Toumani Diabate - Ali & Toumani         NaN
# 487                              Kvelertak - Kvelertak         NaN
# 488             Sparrow & the Workshop - Crystals Fall         NaN
# 489                    Triptykon - Eparistera Daimones         NaN
# 490                                  Actress - Splazsh         NaN
#
# [491 rows x 2 columns]

# %%
# + is for space
# %26 is &



top10.iloc[:, 0]
# Out:
# 0                                             Year: 1970
# 1                        Grateful Dead - American Beauty
# 2                                      Santana - Abraxas
# 3                                 The Stooges - Funhouse
# 4                             Miles Davis - Bitches Brew
#                              ...
# 486    Ali Farka Toure & Toumani Diabate - Ali & Toumani
# 487                                Kvelertak - Kvelertak
# 488               Sparrow & the Workshop - Crystals Fall
# 489                      Triptykon - Eparistera Daimones
# 490                                    Actress - Splazsh
# Name: Unnamed: 0, Length: 491, dtype: object

# %%
substring = "Year: "

album
#looping  through all entries of top 10 albums from 1970 - 2010
#10 step skips to another year
for x in range(0, 490, 10):
    
    #making sure we catch all 10 albums inside with each step
    for y in range(10):
        
        #each entry is stored in result var
        result = str(top10.iloc[:,0][x+y])
        
        #if entry is Year: xxxx
        if substring in str(result):
            print(result)
        
        #if entry is artist/album
        else:
            print(result.split(" - "))
# Out:
# Year: 1970
# ['Grateful Dead', 'American Beauty']
# ['Santana', 'Abraxas']
# ['The Stooges', 'Funhouse']
# ['Miles Davis', 'Bitches Brew']
# ['Derek and The Dominos', 'Layla and Other Assorted Love Songs']
# ['The Velvet Underground', 'Loaded']
# ['James Taylor', 'Sweet Baby James']
# ['Randy Newman', '12 Songs']
# ['The Last Poets', 'The Last Poets']
# ['Grateful Dead', "Workingman's Dead"]
# ['nan']
# Year: 1971
# ['David Bowie', 'Hunky Dory']
# ['Led Zeppelin', 'Led Zeppelin IV']
# ['Joni Mitchell', 'Blue']
# ['T. Rex', 'Electric Warrior']
# ['Mahavishnu Orchestra', 'The Inner Mounting Flame']
# ['The Rolling Stones', 'Sticky Fingers']
# ['Colin Blunstone', 'One Year']
# ['The Who', "Who's Next"]
# ['Can', 'Tago Mago']
# ['Rod Stewart', 'Every Picture Tells a Story']
# ['nan']
# Year: 1972
# ['David Bowie', 'The Rise and Fall of Ziggy Stardust and the Spiders from Mars']
# ['Stevie Wonder', 'Talking Book']
# ['Paul Simon', 'Paul Simon']
# ['Jimmy Cliff', 'The Harder They Come']
# ...

# %%
"https://dr.loudness-war.info/album/list?artist=<artist>&album=bitches+brew"

from selenium import webdriver

dr = webdriver.Chrome()

site = 'https://dr.loudness-war.info/album/list?artist='

artist = "Stevie Wonder"

if " " in artist:
    artist = artist.replace(" ", "+")
    
    
if "&" in artist:
    artist = artist.replace("&", "%26")
    
album = "Songs in the Key of Life"
    

url = site + artist

dr.get(url)

bs = BeautifulSoup(dr.page_source,"lxml")

bs
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/build/app.c80b9dd3.css" rel="stylesheet"/>
# <title>Album list - Dynamic Range DB</title>
# </head>
# <body>
# <div class="container">
# <nav class="navbar navbar-expand-lg navbar-light bg-light mb-4">
# <div class="container-fluid">
# <a class="navbar-brand" href="/">Dynamic Range DB</a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav me-auto mb-2 mb-lg-0">
# <li class="nav-item">
# <a class="nav-link" href="/album/add">Upload</a>
# </li>
# <li class="nav-item dropdown">
# ...

# %%
bs.find_all("td")
# Out:
# [<td><a href="/?artist=Stevie%20Wonder">Stevie Wonder</a></td>,
#  <td><a href="/album/view/200276">Stevie At The Beach</a></td>,
#  <td>2008</td>,
#  <td>
#  <span class="badge-dr badge-dr-09">09</span>
#  </td>,
#  <td>
#  <span class="badge-dr badge-dr-07">07</span>
#  </td>,
#  <td>
#  <span class="badge-dr badge-dr-10">10</span>
#  </td>,
#  <td>Lossless</td>,
#  <td>CD</td>,
#  <td><a href="/?artist=Stevie%20Wonder">Stevie Wonder</a></td>,
#  <td><a href="/album/view/199456">Signed Sealed &amp; Delivered</a></td>,
#  <td>1987</td>,
#  <td>
#  <span class="badge-dr badge-dr-11">11</span>
#  </td>,
#  <td>
#  <span class="badge-dr badge-dr-10">10</span>
#  </td>,
#  <td>
#  <span class="badge-dr badge-dr-12">12</span>
#  </td>,
#  <td>Lossless</td>,
#  <td>CD</td>,
#  <td><a href="/?artist=Stevie%20Wonder">Stevie Wonder</a></td>,
#  <td><a href="/album/view/193802">Songs In The Key Of Life CD2 [SHM-CD]</a></td>,
#  <td>2009</td>,
#  <td>
# ...

# %%
bs.find_all("td")
td = bs.find_all("td")

alb_links = []

for x in range(len(td)):
    
    if td[x].find("a"):
        alb_links.append(td[x])
        #print(x.contents[0])
        
        content = td[x].contents[0]
        print(content.contents[0])
        
        if album in str(content.contents[0]):
            index = x
        
print(int(td[index+2].contents[1].contents[0]))
    #print(x.find("a"))
    #print("type: " + str(type(x.find("a"))))

#print(alb_links)
# Out:
# Stevie Wonder
# Stevie At The Beach
# Stevie Wonder
# Signed Sealed & Delivered
# Stevie Wonder
# Songs In The Key Of Life CD2 [SHM-CD]
# Stevie Wonder
# Songs In The Key Of Life CD1 [SHM-CD]
# Stevie Wonder
# Ballad Collection
# Stevie Wonder
# Music of My Mind [POCT-1808; Japan]
# Stevie Wonder
# Talking Book
# Stevie Wonder
# Someday At Christmas [A Motown Compact Classic]
# Stevie Wonder
# Songs in the Key of Life (Disc 2)
# Stevie Wonder
# Songs in the Key of Life (Disc 1)
# Stevie Wonder
# Stevie Wonder's Original Musiquarium 1
# Stevie Wonder
# Song Review - A Greatest Hits Collection
# Stevie Wonder
# Mono Singles
# Stevie Wonder
# Essential
# Stevie Wonder
# Talking Book
# Stevie Wonder
# Music of my mind (1972)
# Stevie Wonder
# My Cherie Amour (1968)
# Stevie Wonder
# Where I'm Coming From
# Stevie Wonder
# Songs In The Key of Life (Blu-Ray)(2.0 DTS-HD Master Audio 24/96)
# Stevie Wonder
# Where I'm Coming From
# Stevie Wonder
# Songs in the Key of Life
# Stevie Wonder
# ...

# %%
#dict to store all years and their average dynamic ranges
DynRanges = {}

substring = "Year: "

album = ""
artist = ""


dr = webdriver.Chrome()

site = 'https://dr.loudness-war.info/album/list?artist='
    
index = 0

year = 0

#looping  through all entries of top 10 albums from 1970 - 2010
#10 step skips to another year
for x in range(0, 490, 10):
    
    ranges = []
    
    #making sure we catch all 10 albums inside with each step
    for y in range(10):
        
        
        #each entry is stored in result var
        result = str(top10.iloc[:,0][x+y])
        
        #if entry is Year: xxxx
        if substring in str(result):
            year = int(result[6:10])
            
        
        #if entry is artist/album
        else:
            result = result.split(" - ")
            
            #album
            artist = result[0]
            
            album = result[1]
            
            if " " in artist:
                artist = artist.replace(" ", "+")


            if "&" in artist:
                artist = artist.replace("&", "%26")
                
            url = site + artist

            dr.get(url)

            bs = BeautifulSoup(dr.page_source,"lxml")
            
            td = bs.find_all("td")


            for z in range(len(td)):

                if td[z].find("a"):

                    #shows content inside td tag; a href tag is shown
                    content = td[z].contents[0]
                    
                    #this is actual album  and artist name inside a link tag
                    #content.contents[0]

                    if album in str(content.contents[0]):
                        index = z
                        break
                        
            #finding tag and the album's dynamic range
            try:
                ranges.append(int(td[index+2].contents[1].contents[0]))
            except IndexError:
                continue
                
            print("year: " + str(year))
            print("album: " + str(album))
            print("artist: " + str(artist))
            print("dr: " + str(int(td[index+2].contents[1].contents[0])))
            
            
    avg_dr = sum(ranges) / len(ranges)
    
    try:
        DynRanges.update(year, avg_dr)
    except TypeError:
        continue
    
    
print(DynRanges)
# Out:
# year: 1970
# album: American Beauty
# artist: Grateful+Dead
# dr: 10
# year: 1970
# album: Unknown Pleasures
# artist: Joy+Division
# dr: 8
# year: 1970
# album: The Harder They Come
# artist: Jimmy+Cliff
# dr: 12
# year: 1970
# album: Metal Box
# artist: Public+Image+Ltd.
# dr: 12
# year: 1970
# album: Led Zeppelin IV
# artist: Led+Zeppelin
# dr: 9
# year: 1970
# album: I'm Still in Love with You
# artist: Al+Green
# dr: 13
# year: 1970
# album: Criminal Minded
# artist: Boogie+Down+Productions
# dr: 11
# year: 1970
# album: Birds of Fire
# artist: Mahavishnu+Orchestra
# dr: 11
# year: 1970
# album: Workingman's Dead
# artist: Grateful+Dead
# dr: 9
# year: 1970
# album: Abraxas
# artist: Santana
# dr: 11
# year: 1970
# album: Jesus of Cool
# artist: Nick+Lowe
# dr: 14
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...

# %%
#dict to store all years and their average dynamic ranges
DynRanges = {}

substring = "Year: "

album = ""
artist = ""


dr = webdriver.Chrome()

site = 'https://dr.loudness-war.info/album/list?artist='
    


year = 0

#looping  through all entries of top 10 albums from 1970 - 2010
#10 step skips to another year
for x in range(0, 490, 12):
    
    ranges = []
    
    #making sure we catch all 10 albums inside with each step
    for y in range(11):
        
        index = 0
        
        #each entry is stored in result var
        result = str(top10.iloc[:,0][x+y])
        
        #if entry is Year: xxxx
        if substring in str(result):
            year = int(result[6:10])
            
        
        #if entry is artist/album
        else:
            result = result.split(" - ")
            
            #album
            artist = result[0]
            
            album = result[1]
            
            if " " in artist:
                artist = artist.replace(" ", "+")


            if "&" in artist:
                artist = artist.replace("&", "%26")
                
            url = site + artist

            dr.get(url)

            bs = BeautifulSoup(dr.page_source,"lxml")
            
            td = bs.find_all("td")

            for z in range(len(td)):

                if td[z].find("a"):

                    #shows content inside td tag; a href tag is shown
                    content = td[z].contents[0]
                    
                    #this is actual album  and artist name inside a link tag
                    final = content.contents[0]

                    if album in str(final):
                        index = z
                        break

            
            #finding tag and the album's dynamic range
            try:
                ranges.append(int(td[index+2].contents[1].contents[0]))
            except IndexError:
                continue

            # print("year: " + str(year))
            # print("album: " + str(album))
            # print("artist: " + str(artist))
            # print("dr: " + str(int(td[index+2].contents[1].contents[0])))
            
            
    avg_dr = sum(ranges) / len(ranges)
    
    try:
        DynRanges[year] = avg_dr
    except TypeError:
        continue
    
print(DynRanges)
#{1970: 11.375, 1971: 10.571428571428571, 1972: 11.666666666666666, 1973: 11.571428571428571, 1974: 11.833333333333334, 1975: 11.5, 1976: 13.0, 1977: 9.666666666666666, 1978: 12.0, 1979: 11.857142857142858, 1980: 11.833333333333334, 1981: 11.333333333333334, 1982: 11.25, 1983: 13.0, 1984: 11.5, 1985: 11.777777777777779, 1986: 12.714285714285714, 1987: 10.833333333333334, 1988: 11.0, 1989: 12.125, 1990: 12.5, 1991: 11.25, 1992: 12.0, 1993: 11.428571428571429, 1994: 10.6, 1995: 9.571428571428571, 1996: 9.88888888888889, 1997: 8.555555555555555, 1998: 9.5, 1999: 10.4, 2000: 9.555555555555555, 2001: 8.666666666666666, 2002: 7.75, 2003: 9.4, 2004: 8.333333333333334, 2005: 9.333333333333334, 2006: 8.5, 2007: 9.428571428571429, 2008: 7.166666666666667, 2009: 9.5, 2010: 8.428571428571429}
# Out:
# {1970: 11.375, 1971: 10.571428571428571, 1972: 11.666666666666666, 1973: 11.571428571428571, 1974: 11.833333333333334, 1975: 11.5, 1976: 13.0, 1977: 9.666666666666666, 1978: 12.0, 1979: 11.857142857142858, 1980: 11.833333333333334, 1981: 11.333333333333334, 1982: 11.25, 1983: 13.0, 1984: 11.5, 1985: 11.777777777777779, 1986: 12.714285714285714, 1987: 10.833333333333334, 1988: 11.0, 1989: 12.125, 1990: 12.5, 1991: 11.25, 1992: 12.0, 1993: 11.428571428571429, 1994: 10.6, 1995: 9.571428571428571, 1996: 9.88888888888889, 1997: 8.555555555555555, 1998: 9.5, 1999: 10.4, 2000: 9.555555555555555, 2001: 8.666666666666666, 2002: 7.75, 2003: 9.4, 2004: 8.333333333333334, 2005: 9.333333333333334, 2006: 8.5, 2007: 9.428571428571429, 2008: 7.166666666666667, 2009: 9.5, 2010: 8.428571428571429}

# %%
years = []
num = 1970
for x in range(41):
    years.append(num+x)

print(years)

x3 = years

y3 = []

for i in DynRanges:
    y3.append(DynRanges[i])
# Out:
# [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]

# %%
dynrangechart = plt.figure(figsize=(14, 10))
plt.plot(x3, y3, color='green')

plt.title(label= 'Dynamic Ranges of Albums 1970-2010')
plt.xlabel("Years")
plt.ylabel("Dynamic Range in dB")

plt.grid(True)

dynrangechart

# %%
finalchart = plt.figure(figsize=(14, 10))
plt.plot(x1, y1, color='red', label='United Kingdom')
plt.plot(x1, y2, color='orange', label='United States of America')
plt.plot(x3, y3, color='green', label='Avg Dynamic Range of albums')
plt.title(label= 'Prevalence of hearing loss rates in the US and UK, combined with dynamic range data')
plt.xlabel("Years")
#plt.ylabel("Cases in tens of millions")
plt.legend()
plt.grid(True)

# %%
fig, ax_left = plt.subplots()

ax_left.plot(x1, y1, color='red', label='United Kingdom')
ax_left.plot(x1, y1, color='blue', label='United States of America')
ax_left.set_ylabel('Rates')

ax_right = ax_left.twinx()
ax_right.plot(x3, y3, color='green', label='Average Dynamic Range of Albums')
ax_right.set_ylabel('Dynamic Range')
plt.legend()
#plt.figure(figsize=(14, 10))
plt.show()
